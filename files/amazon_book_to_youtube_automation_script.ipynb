# %% [markdown]
# <a href="https://colab.research.google.com/github/ap0plexik/notebooks/blob/trunk/files/amazon_book_to_youtube_automation_script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is from Siraj Raval on YT: https://www.youtube.com/watch?v=4r-_iW8fmWU
#
# [Katherine_AI YT channel](https://www.youtube.com/@katherine_AI/shorts)

# %% [markdown]
# 1.0  One-Time Pre-work Setup
#   - 1.1 Create Google Sheet
#   - 1.2 Set up Google Deploy Script
#   - 1.3 Generate a Soundtrack
#   - 1.4 Generate Avatar Image
#   - 1.5 Generate some Animations
#
# 2.0  Real Work
#   - 2.1 Find a Book using Twitter
#   - 2.2 Generate a Script
#   - 2.3 Generate dID Video
#   - 2.4 Assemble the final video
#   - 2.5 Add video information to Google Sheet
#
# 3.0  Post to YouTube

# %% [markdown]
# # 1. Prep work

# %% [markdown]
# This is work you can do before checking Twitter for a Book to sell. Most of it will only need to be done once.

# %% [markdown]
# ## 1.1 Set up a Google Sheet

# %% [markdown]
# Google Sheet Setup Instructions
# *NEED TO ADD INSTRUCTIONS ON GETTING THE ID AND WHAT COLS TO USE*

# %% [markdown]
# ## 1.2 Set up the Deploy Script for Google Sheets

# %% [markdown]
# - Go to https://script.google.com/
# - Paste in the code below to run this as an 'app script'
# - Enable the Google Sheets and Youtube API
#
# 🛑 This JS code is an app script in Google Scripts.
#
# ```javascript
# function myFunction() {
#
#  print('hello')
#
#  // Open a document by ID.
#   var doc = DocumentApp.openById(googleSheetId);
#
# }
#
# function getGeneratedVideoURLs() {
#   var sheet = SpreadsheetApp.getActiveSheet();
#   var data = sheet.getDataRange().getValues();
#   for (var i = 0; i < data.length; i++) {
#     Logger.log('Generated Video URL: ' + data[i][0]);
#   }
# }
#
# function upload()
# { try
#
#   /**
#    * Config.
#    **/
#   var ytVideoTitle = ""           // "Video by Katherine"
#   var ytVideoDescription = ""     // "This is a video about Katherine AI" Include Amazon URL
#   var sourceVideoUrl = ""         // The URL to the Final Video file (generated by ShotStack)
#   var ytVideoTags = []            // Array ["funny"]
#
#   { var video = UrlFetchApp.fetch(sourceVideoUrl);
#   YouTube.Videos.insert(
#     { snippet:
#       { title: ytVideoTitle, description: ytVideoDescription, tags: ytVideoTags }, status: { privacyStatus: "private", },
#     }, "snippet,status", video);
#
#   return ContentService.createTextOutput("done") }
#   catch (err) {
#     return ContentService.createTextOutput(err.message) }
# }
#
#
# upload();
# ```

# %% [markdown]
# ## 1.3 Generate Soundtrack

# %%
from pydub import AudioSegment
from pydub.generators import Sine, Square

# Set the tempo and duration of the beat
tempo = 120  # beats per minute
duration = 4000  # milliseconds

# Generate the audio signal for each instrument
kick = Sine(60).to_audio_segment(duration=duration, volume=-12)
snare = Sine(90).to_audio_segment(duration=duration, volume=-12)
square = Square(440).to_audio_segment(duration=duration, volume=-12)

# Create a new audio segment to hold the beat
beat = AudioSegment.silent(duration=duration)

# Add the audio signal for each instrument to the beat
beat = beat.overlay(kick, position=0)
beat = beat.overlay(snare, position=1000)
beat = beat.overlay(square, position=2000)

# Export the beat as an MP3 file
beat.export("soundtrack.mp3", format="mp3")

# %% [markdown]
# ## 1.4 Generate an Avatar Image

# %% [markdown]
# ## 1.5 Generate some Animations

# %% [markdown]
# - Let's install manim, the math animation library in python by 3blue1brown on Youtube
# - This will take 2-3 minutes to install. its big. may require a runtime restart.
# - If you don't want to wait, go here: https://hub.ovh2.mybinder.org/user/manimcommunity-jupyter_examples-dr3u00vk/notebooks/First%20Steps%20with%20Manim.ipynb

# %%
# !sudo apt update
# !sudo apt install libcairo2-dev ffmpeg \
    texlive texlive-latex-extra texlive-fonts-extra \
    texlive-latex-recommended texlive-science \
    tipa libpango1.0-dev
# !pip install manim
# !pip install IPython==7.9.0

# %% [markdown]
# Now let's ask OpenAI to generate us some manim code

# %%
import openai

openai.api_key = openAIapiKey

# "Summarize the item.description in two sentences".
prompt = "/* " + maximProptPrefix + " " + str(book_summary) + "*/"

manim_code = openai.Completion.create(
  model = "code-davinci-002",
  prompt = prompt,
  temperature = 1,
  max_tokens = 100,
  top_p = 1,
  frequency_penalty = 0,
  presence_penalty = 0
)

print(manim_code)

# %% [markdown]
# 🛑 Unfortunately, they're still not that great at it. ChatGPT > GPT-3 at this by far. So we'll just type some in here to animate linear algebra.

# %%
# NOTE: this Specific is for an animation of Linear Algebra

# %manim -qm -v WARNING matrixTest

from manim import *
import numpy as np
class matrixTest(Scene):
	
	def construct(self):
		A = np.array([[-1, 5], [7, 11]])
		B = np.array([[2, 3], [-8, 0]])
		C = np.dot(A, B)
		
		stuff = VGroup(Matrix(A), Matrix(B), Matrix(C))
		matrixA = stuff[0]
		matrixB = stuff[1]
		matrixC = stuff[2]
		matrixA.height = 2.5
		matrixB.height = 2.5
		matrixA.color = PURPLE
		matrixB.color = RED
		Dot = Tex(".", color=WHITE, font_size = 200)
		Equals = Tex("=", color=WHITE, font_size = 100)
		bOpen = Tex("[", color=WHITE, font_size = 100)
		bClose = Tex("]", color=WHITE, font_size=100)
		bOpen1 = Tex("[", color=WHITE, font_size=200)
		bClose1 = Tex("]", color=WHITE, font_size=200)
		
		
		self.play(Write(matrixA))
		self.play(matrixA.animate.scale(1).to_corner(UP+LEFT*2))
		
		Dot.next_to(matrixA, RIGHT)
		self.play(Write(Dot))
		
		self.play(Write(matrixB))
		self.play(matrixB.animate.scale(1).next_to(Dot, RIGHT))
		
		Equals.next_to(matrixB, RIGHT)
		self.play(Write(Equals))
		
		matrixC.next_to(Equals)
		C_elements = VGroup(*matrixC)
		for i in C_elements[1:]:
			i.height = 2.5
			self.play(Write(i))
		C_elements = VGroup(*C_elements[0])
		A_rows = matrixA.get_rows()
		A = VGroup(A_rows[0], A_rows[0], A_rows[1], A_rows[1])
		B_columns = matrixB.get_columns()
		B = VGroup(B_columns[0], B_columns[1], B_columns[0], B_columns[1])
		
		for r, c, ans in zip(A.copy(), B.copy(), C_elements.copy()):
			_bOpen = bOpen.copy()
			_bClose = bClose.copy()
			_bOpen1 = bOpen1.copy()
			_bClose1 = bClose1.copy()
			_Dot = Dot.copy()
			_r = r.copy()
			_c = c.copy()
			_bOpen.next_to(matrixA, DOWN*3)
			self.play(Write(_bOpen))
			self.play(_r.set_color(BLUE).animate.next_to(_bOpen))
			_bClose.next_to(_r, RIGHT)
			self.play(Write(_bClose))
			_Dot.next_to(_bClose, RIGHT)
			self.play(Write(_Dot))
			_bOpen1.next_to(_Dot, RIGHT)
			self.play(Write(_bOpen1))
			self.play(_c.set_color(YELLOW).animate.next_to(_bOpen1))
			_bClose1.next_to(_c, RIGHT)
			self.play(Write(_bClose1))
			g = VGroup(_bOpen, _r, _bClose, _Dot, _bOpen1, _c, _bClose1)
			ans.font_size = 60
			ans.set_color(PURE_GREEN)
			self.play(Transform(g, ans))
			
		self.wait()
		self.play(Write(Text(maximVideoText, font_size=80)))
		self.wait()

# %% [markdown]
# # 2.0 Real Work

# %%
# !pip install snscrape       # Scrape Amazon Book Reviews on Twitter
# !pip install vaderSentiment # Identify the Most Positive Review
# !pip install openai         # Generate 30 second video script 
# !pip install pydub          # Generate Background Music
# !pip install shotstack_sdk  # Video Editing API

# Config
twitterSearchString = ""    # "Machine Learning Textbook amazon"
openAIapiKey = ""           # "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"
maximProptPrefix = ""       # "Create a short manim script in python to animate"
maximVideoText = ""         # "Code in the description"
shotStackDeveloperKey = ""  # "vbtcV58kDf..."
avatarImage = ""            # Image URL generated by Midjourney or whatever. https://i.imgur.com/rkDNaTq.png 
soundTrackUrl = ""          # URL to MP3 file.

dIdApiKey = ""              # "eyJhbGci..."
dIdScriptPrefix = ""        # "Hey! It's your favorite AI teacher Katherine."
dIdScriptSuffix = ""        # " Buy it on Amazon now!"

googleSheetId = ""          # '1BxiMVs0XRA5nFMdKvBdBZjgmUUqptlbs74OgvE2upms'
googleSheetRange = ""       # 'Class Data!A2:E'

# %% [markdown]
# ## 2.1 Find a Book using Twitter

# %% [markdown]
# Scrape Tweets with a certain text (like "Machine Learning textbook Amazon") to find a book to sell.

# %%
import snscrape.modules.twitter as sntwitter
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd

analyzer = SentimentIntensityAnalyzer()
limit= 10 
tweets_list =[] 
for tweet in sntwitter.TwitterSearchScraper(twitterSearchString).get_items(): 
    if len(tweets_list)== limit: 
        break 
    else: 
        tweets_list.append([tweet.date, tweet.content, tweet.user.username, tweet.user.displayname, tweet.user.description,  
        tweet.replyCount, tweet.retweetCount,tweet.likeCount , tweet.quoteCount, tweet.lang, tweet.source]) 
df = pd.DataFrame(tweets_list,columns=["date", "tweets", "username", "displayname", "description", "rpcounts", 
                                        "retweetcounts", "likecounts", "quotecount", "languvage", "source"  ])   
print(df)

# %% [markdown]
# - Now we can select 1 tweet to extract the book name and review from
# - If its positive enough (>60 percent sentiment score) we'll promote it

# %%
book_title = df.loc[0,"tweets"]
sentiment = analyzer.polarity_scores(book_title)
print(book_title)
print(sentiment)

# %% [markdown]
# 🛑 Stop Here and get the Book and URL from Amazon

# %% [markdown]
# ## 2.2 - Generate Book Summary Text

# %%
##
# CONFIG: Add your chosen Book Title.
##
book_title = ""
book_url = ""

# %%
import openai

openai.api_key = openAIapiKey

# "Summarize the item.description in two sentences".
prompt = "Summarize this in two sentences: " + book_title

book_summary = openai.Completion.create(
  model = "text-davinci-003",
  prompt = prompt,
  temperature = 1,
  max_tokens = 600,
  top_p = 1,
  frequency_penalty = 0,
  presence_penalty = 0
)

print(book_summary)

# %% [markdown]
# ## 1.3 Generate dID Video
#
# - Lets now generate a video avatar using D-ID
# - We can do this programatically to generate the video on the D ID server

# %%
import requests

url = "https://api.d-id.com/talks"

script = dIdScriptPrefix + book_summary + dIdScriptSuffix

payload = {
    "script": {
        "type": "text",
        "provider": {
            "type": "microsoft",
            "voice_id": "Sara"
        },
        "ssml": "false",
        "input": script
    },
    "config": {
        "fluent": "false",
        "pad_audio": "0.0"
    },
    "source_url": avatarImage
}
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "authorization": "Bearer " + dIdApiKey
}

response = requests.post(url, json=payload, headers=headers)

print(response.text)

# %%
import requests

url = "https://api.d-id.com/talks?limit=100"

headers = {
    "accept": "application/json",
    "authorization": "Bearer " + dIdApiKey
}
response = requests.get(url, headers=headers)
print(response.text)

## @todo ensure this gives a video URL.

# %% [markdown]
# 🛑 After generation, we can pull the video URL from the D-ID server.
# Download it and save it, noting the Video URL in the Google Sheet.

# %% [markdown]
# ## 1.4 Assemble Final Video
#
# We now have
# - dID video
# - Spoken Script
# - Animation
# - Soundtrack
#
# Let's stitch it all together with the ShotStack API

# %%
# Set the Video URL from dID (Step 1.3)
dIDVideoUrl = ''

# %%
from shotstack_sdk.model.soundtrack import Soundtrack
import shotstack_sdk as shotstack
from shotstack_sdk.api import edit_api
from shotstack_sdk.model.video_asset import VideoAsset
from shotstack_sdk.model.image_asset import ImageAsset

from shotstack_sdk.model.clip import Clip
from shotstack_sdk.model.track  import Track
from shotstack_sdk.model.timeline import Timeline
from shotstack_sdk.model.output import Output
from shotstack_sdk.model.edit import Edit

host = 'https://api.shotstack.io/stage'
configuration = shotstack.Configuration(host = host)

configuration.api_key['DeveloperKey'] = shotStackDeveloperKey

with shotstack.ApiClient(configuration) as api_client:
    api_instance = edit_api.EditApi(api_client)

    video_asset = VideoAsset(
        src = dIDVideoUrl,
    )
    
    soundtrack = Soundtrack(
        src = soundTrackUrl,
        effect = 'fadeIn',
        volume = 1.0
    )

    image_asset = ImageAsset(
        src = avatarImage,
    )
    video_clip = Clip(
        asset = video_asset,
        start = 0.0,
        length = 8.0
    )

    image_clip = Clip(
        asset = image_asset,
        start = 4.0,
        length = 4.0,
        fit = 'crop',
        scale = 0.0,
        position = 'center',
        opacity = 1.0,
    )

    track = Track(clips=[video_clip, image_clip])

    # If the soundtrack isn't just BG music, remove it from this line.
    timeline = Timeline(soundtrack=soundtrack, tracks=[track])


    output = Output(
        format = 'mp4',
        resolution = 'sd'
    )

    edit = Edit(
        timeline = timeline,
        output = output
    )

    try:
        api_response = api_instance.post_render(edit)
        print(f"{api_response['response']['id']}")
    except Exception as e:
        print(f"Unable to resolve API call: {e}")
# Out:
# Unable to resolve API call: expected string or bytes-like object

# %% [markdown]
# 🛑 The above response should give you the Render ID.  Set it here.

# %%
###
# Config.
###
shotStackRenderId = '' # "de58c33d-d734-4539-8caa-73d27e4401f5"

# %%
import shotstack_sdk as shotstack
from shotstack_sdk.api import edit_api

host = 'https://api.shotstack.io/stage'
configuration = shotstack.Configuration(host = host)

configuration.api_key['DeveloperKey'] = shotStackDeveloperKey

with shotstack.ApiClient(configuration) as api_client:
    api_instance = edit_api.EditApi(api_client)

    id = shotStackRenderId

    try:
        api_response = api_instance.get_render(id, data=False, merged=True)
        status = api_response['response']['status']

        if status == 'done':
            print(f"{api_response['response']['url']}")
    except Exception as e:
        print(f"Unable to resolve API call: {e}")

# %% [markdown]
# 🛑 Get the Video File from the ShotStack Server and download it.
# Note the URL in your Google Sheet

# %% [markdown]
# # 3.0 Post To YouTube

# %% [markdown]
# You can set this up on a Cron, or just run it manually here.
#
# Use all this python code in your own flask app with a Cron (scheduler) to run once daily.

# %%
## That's it! We'll call that Google Sheet from Google's App Script Service
## in order to auto post it to Youtube. Why? Because Google Auth is difficult
## and finnicky. 

from __future__ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

def main():
    """Shows basic usage of the Sheets API.
    Prints values from a sample spreadsheet.
    """
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    try:
        service = build('sheets', 'v4', credentials=creds)

        # Call the Sheets API
        sheet = service.spreadsheets()
        result = sheet.values().get(spreadsheetId=googleSheetId,
                                    range=googleSheetRange).execute()
        values = result.get('values', [])

        if not values:
            print('No data found.')
            return

        print('Name, Major:')
        for row in values:
            # Print columns A and E, which correspond to indices 0 and 4.
            print('%s, %s' % (row[0], row[4]))
    except HttpError as err:
        print(err)


if __name__ == '__main__':
    main()
# [END sheets_quickstart]
